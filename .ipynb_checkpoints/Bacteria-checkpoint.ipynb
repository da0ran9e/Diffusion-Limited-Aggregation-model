# %%
import numpy as np

# Kích thước     # Số mũ p - trong công thức xác suất      # Đặt virus đầu tiên ở vị trí trên cùng bên trái
def simulate(size, p, x_start, y_start):
    temp_values = []
    # Số virus
    n = 4000
    nVirus = 1

    # Mảng biểu thị nồng độ thức ăn
    C = np.zeros((size, size))
    temp = np.zeros((size, size))

    # Tham số điều chỉnh
    w = 1.89

    # Mảng grow đánh dấu vị trí các virus đã xuất hiện
    grow = np.zeros((size, size))
    grow[x_start, y_start] = 1

    # Với phương pháp lặp SOR, khi tính tại bước k+1 thì ta sẽ có giá trị của
    # bước k+1 tại vị trí (i-1, j) và (i, j-1)
    for i in range(1, size - 1):
        for j in range(1, size - 1):
            C[i, j] = 1


    C[x_start, y_start] = 0

    while True:
        candidate = np.zeros((size, size))
        sumOfChance = 0

        # Tính SOR
        for i in range(1, size - 1):
            for j in range(1, size - 1):
                if C[i, j] != 0:
                    C[i, j] = (w/4) * (C[i+1, j] + C[i-1, j] + C[i, j+1] + C[i, j-1]) + (1-w) * C[i, j]
                if C[i, j] < 0:
                    temp[i, j] = 0
                else:
                    temp[i, j] = C[i, j]

        # Tìm candidates
        for i in range(1, size - 1):
            for j in range(1, size - 1):
                if grow[i, j] == 1:
                    C[i, j] = 0
                    if grow[i-1, j] == 0 and candidate[i-1, j] == 0:
                        candidate[i-1, j] = 1
                    if grow[i+1, j] == 0 and candidate[i+1, j] == 0:
                        candidate[i+1, j] = 1
                    if grow[i, j-1] == 0 and candidate[i, j-1] == 0:
                        candidate[i, j-1] = 1
                    if grow[i, j+1] == 0 and candidate[i, j+1] == 0:
                        candidate[i, j+1] = 1

        # Tính mẫu của P
        for i in range(1, size - 1):
            for j in range(1, size - 1):
                if candidate[i, j] == 1:
                    sumOfChance += C[i, j]**p

        # Random grow
        for i in range(1, size - 1):
            for j in range(1, size - 1):
                if candidate[i, j] == 1:
                    randPos = np.random.rand() / 10
                    curChance = (C[i, j]**p) / sumOfChance
                    if randPos < curChance:
                        grow[i, j] = 1
                        if nVirus < 4000:
                            nVirus += 1
                            
        temp_values.append(temp.copy())
        print(nVirus, end="\r")
        
        if nVirus == 4000:
            return temp_values
            break

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
        
def run_sim(size = 201, p = 2, x_start = 2, y_start = 100, name = ''):
    filename = '{0}x{0}p{1}plot{2}'.format(size-1, p, name)
    try:
        # Load the array from the file if exist
        temp_values = np.load('data/' + filename + '.npy')
    except FileNotFoundError:
        temp_values = simulate(size, p, x_start, y_start)
        np.save('data/' + filename + '.npy', temp_values)

    temp = temp_values[-1]
    
    x = np.arange(size)
    y = np.arange(size)
    X, Y = np.meshgrid(x, y)

    fig, (ax, ax_top) = plt.subplots(1, 2, figsize=(10, 5), subplot_kw={'projection': '3d'})
    ax.plot_surface(X, Y, temp, cmap='jet')
    ax.view_init(azim=-120, elev=30)
    
    ax_top.contourf(X, Y, temp, cmap='jet')
    ax_top.view_init(azim=-90, elev=90)
    ax_top.set_zticks([])
    
    plt.savefig(filename + '.png', transparent=True)
    plt.show(block=False)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation

def animate(size = 201, p = 2, x_start = 2, y_start = 100, name = ''):
    filename = '{0}x{0}p{1}plot{2}'.format(size-1, p, name)
    
    temp_values = np.load('data/' + filename + '.npy')
    
    x = np.arange(size)
    y = np.arange(size)
    X, Y = np.meshgrid(x, y)
    max_z = np.max(temp_values[0])

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.set_zlim(0, max_z) 
    plot = ax.plot_surface(X, Y, temp_values[0], cmap='jet')

    # Define the update function for the animation
    def update_plot(num, plot, ax):
        # Clear the current plot
        ax.cla()
        ax.set_zlim(0, max_z) 
        plot = ax.plot_surface(X, Y, temp_values[num], cmap='jet')

        return plot

    # Create the animation
    ani = animation.FuncAnimation(fig, update_plot, frames=len(temp_values), fargs=(plot, ax), interval=20)

    # Save the animation as a GIF
    ani.save(filename + '.gif', writer='pillow')

# %%
run_sim(p = 0)
animate(p = 0)
# Out:
# 816

# %%
run_sim(p = 1)

# %%
temp2 = run_sim(p = 2)

# %%
run_sim(size = 501, p = 0, x_start = 2, y_start = 250)

# %%
run_sim(size = 501, p = 1, x_start = 2, y_start = 250)

# %%
run_sim(size = 501, p = 2, x_start = 2, y_start = 250)

# %%
run_sim(size = 501, p = 0, x_start = 250, y_start = 250, name = '-mid')
# Out:
# 3993

# %%
run_sim(size = 501, p = 1, x_start = 250, y_start = 250, name = '-mid')
# Out:
# 3998

# %%
run_sim(size = 501, p = 2, x_start = 250, y_start = 250, name = '-mid')
# Out:
# 3999
